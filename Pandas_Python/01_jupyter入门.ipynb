# %% [markdown]
# # jupyter入门

# %%
# 命令模式常用快捷键：A -> 新建cell在上方，B -> 新建cell在下方
# DD -> 删除当前cell，M - > 切换为MarkDown模式，Y -> 切换为代码模式
# 通用模式快捷键：Ctrl + Enter -> 运行当前cell，
# Shift + Enter -> 运行当前cell并跳转到下一个cell

# %% [markdown]
# # MarkDown写法

# %% [markdown]
# # 一级标题
# ## 二级标题
# - 一级缩进
#      - 二级缩进
#          - 三级缩进
# > 123
